# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# display all the columns of the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
df = pd.read_csv('finalTrain_Apr17_practice.csv')

# %%
df.head(10)
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
# 5  0x3af3      MUMRES15DEL03                 29.0                      4.5
# 6  0x3aab      MYSRES01DEL01                 35.0                      4.0
# 7  0x689b     PUNERES20DEL01                 33.0                      4.2
# 8  0x6f67      HYDRES14DEL01                 34.0                      4.9
# 9  0xc9cf      KOLRES15DEL03                 21.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
# 5            19.176269             72.836721                   19.266269
# 6            12.311072             76.654878                   12.351072
# 7            18.592718             73.773572                   18.702718
# 8            17.426228             78.407495                   17.496228
# 9            22.552672             88.352885                   22.582672
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022       21:55             22:10
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
# 5                    72.926721  02-04-2022       20:25             20:35
# 6                    76.694878  01-03-2022       14:55             15:10
# 7                    73.883572  16-03-2022       20:30             20:40
# 8                    78.477495  20-03-2022       20:40             20:50
# 9                    88.382885  15-02-2022       21:15             21:30
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
# 5         Sandstorms                  Jam                  2        Buffet
# 6              Windy                 High                  1          Meal
# 7         Sandstorms                  Jam                  2         Snack
# 8             Cloudy                  Jam                  0         Snack
# 9              Windy                  Jam                  0          Meal
#
#     Type_of_vehicle  multiple_deliveries Festival           City  \
# 0        motorcycle                  3.0       No  Metropolitian
# 1        motorcycle                  1.0       No  Metropolitian
# 2           scooter                  1.0       No  Metropolitian
# 3        motorcycle                  0.0       No  Metropolitian
# 4           scooter                  1.0       No  Metropolitian
# 5  electric_scooter                  1.0       No  Metropolitian
# 6           scooter                  1.0       No  Metropolitian
# 7        motorcycle                  1.0       No  Metropolitian
# 8        motorcycle                  NaN       No  Metropolitian
# 9        motorcycle                  1.0       No          Urban
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41
# 5                20
# 6                33
# 7                40
# 8                41
# 9                15

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['id', 'delivery_person_id', 'delivery_person_age',
#        'delivery_person_ratings', 'restaurant_latitude',
#        'restaurant_longitude', 'delivery_location_latitude',
#        'delivery_location_longitude', 'order_date', 'time_orderd',
#        'time_order_picked', 'weather_conditions', 'road_traffic_density',
#        'vehicle_condition', 'type_of_order', 'type_of_vehicle',
#        'multiple_deliveries', 'festival', 'city', 'time_taken (min)'],
#       dtype='object')

# %%
df.shape
# Out:
# (45584, 20)

# %%
df.describe()
# Out:
#        delivery_person_age  delivery_person_ratings  restaurant_latitude  \
# count         43730.000000             43676.000000         45584.000000
# mean             29.566911                 4.633774            17.017948
# std               5.815064                 0.334744             8.185674
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              35.000000                 4.900000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        restaurant_longitude  delivery_location_latitude  \
# count          45584.000000                45584.000000
# mean              70.229684                   17.465480
# std               22.885575                    7.335562
# min              -88.366217                    0.010000
# 25%               73.170000                   12.988453
# 50%               75.897963                   18.633934
# 75%               78.044095                   22.785049
# max               88.433452                   31.054057
#
#        delivery_location_longitude  vehicle_condition  multiple_deliveries  \
# count                 45584.000000       45584.000000         44591.000000
# mean                     70.844161           1.023385             0.744635
# std                      21.120578           0.839055             0.572510
# min                       0.010000           0.000000             0.000000
# 25%                      73.280000           0.000000             0.000000
# 50%                      76.002574           1.000000             1.000000
# 75%                      78.107044           2.000000             1.000000
# max                      88.563452           3.000000             3.000000
#
#        time_taken (min)
# count      45584.000000
# mean          26.293963
# std            9.384298
# min           10.000000
# 25%           19.000000
# 50%           26.000000
# 75%           32.000000
# max           54.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           45584 non-null  object
#  1   delivery_person_id           45584 non-null  object
#  2   delivery_person_age          43730 non-null  float64
#  3   delivery_person_ratings      43676 non-null  float64
#  4   restaurant_latitude          45584 non-null  float64
#  5   restaurant_longitude         45584 non-null  float64
#  6   delivery_location_latitude   45584 non-null  float64
#  7   delivery_location_longitude  45584 non-null  float64
#  8   order_date                   45584 non-null  object
#  9   time_orderd                  43853 non-null  object
#  10  time_order_picked            45584 non-null  object
#  11  weather_conditions           44968 non-null  object
#  12  road_traffic_density         44983 non-null  object
#  13  vehicle_condition            45584 non-null  int64
#  14  type_of_order                45584 non-null  object
#  15  type_of_vehicle              45584 non-null  object
#  16  multiple_deliveries          44591 non-null  float64
#  17  festival                     45356 non-null  object
#  18  city                         44384 non-null  object
#  19  time_taken (min)             45584 non-null  int64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 7.0+ MB

# %%
df.isnull().sum()
# Out:
# id                                0
# delivery_person_id                0
# delivery_person_age            1854
# delivery_person_ratings        1908
# restaurant_latitude               0
# restaurant_longitude              0
# delivery_location_latitude        0
# delivery_location_longitude       0
# order_date                        0
# time_orderd                    1731
# time_order_picked                 0
# weather_conditions              616
# road_traffic_density            601
# vehicle_condition                 0
# type_of_order                     0
# type_of_vehicle                   0
# multiple_deliveries             993
# festival                        228
# city                           1200
# time_taken (min)                  0
# dtype: int64

# %% [raw]
# df.drop(['id','delivery_person_id'],axis=1, inplace=True)

# %%
df = df.rename(columns={'time_taken (min)': 'time_taken_min'})

# %%
df[df.duplicated()]
# no data is duplicated
# Out:
# Empty DataFrame
# Columns: [id, delivery_person_id, delivery_person_age, delivery_person_ratings, restaurant_latitude, restaurant_longitude, delivery_location_latitude, delivery_location_longitude, order_date, time_orderd, time_order_picked, weather_conditions, road_traffic_density, vehicle_condition, type_of_order, type_of_vehicle, multiple_deliveries, festival, city, time_taken_min]
# Index: []

# %%
df.head(5)
# Out:
#        id delivery_person_id  delivery_person_age  delivery_person_ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    restaurant_latitude  restaurant_longitude  delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    delivery_location_longitude  order_date time_orderd time_order_picked  \
# 0                    78.116106  12-02-2022       21:55             22:10
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
#
#   weather_conditions road_traffic_density  vehicle_condition type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   type_of_vehicle  multiple_deliveries festival           city  time_taken_min
# 0      motorcycle                  3.0       No  Metropolitian              46
# 1      motorcycle                  1.0       No  Metropolitian              23
# 2         scooter                  1.0       No  Metropolitian              21
# 3      motorcycle                  0.0       No  Metropolitian              20
# 4         scooter                  1.0       No  Metropolitian              41

# %% [markdown]
# ## In data analysis we will analyze to find the below stuff
#
# 1. Missing values
# 2. All the numerical variables
# 3. Distribution of the numerical variables
# 4. Categorical variables
# 5. outliers
# 6. Relationship b/w independent and dependent features
# 7. Correlations (Feature selection)

# %%
list(df.columns)
# Out:
# ['id',
#  'delivery_person_id',
#  'delivery_person_age',
#  'delivery_person_ratings',
#  'restaurant_latitude',
#  'restaurant_longitude',
#  'delivery_location_latitude',
#  'delivery_location_longitude',
#  'order_date',
#  'time_orderd',
#  'time_order_picked',
#  'weather_conditions',
#  'road_traffic_density',
#  'vehicle_condition',
#  'type_of_order',
#  'type_of_vehicle',
#  'multiple_deliveries',
#  'festival',
#  'city',
#  'time_taken_min']

# %%
# features having missing values
features_with_na = [feature for feature in df.columns if df[feature].isnull().sum()>1 ]

# %%
features_with_na
# Out:
# ['delivery_person_age',
#  'delivery_person_ratings',
#  'time_orderd',
#  'weather_conditions',
#  'road_traffic_density',
#  'multiple_deliveries',
#  'festival',
#  'city']

# %%
df['delivery_person_age'].isnull().sum()
# Out:
# 1854

# %%
df['delivery_person_age'].isnull().median()
# Out:
# 0.0

# %%
np.round(df['delivery_person_age'].isnull().mean()*100,4)
# Out:
# 4.0672

# %%
# mean of missing values
for feature in features_with_na:
    print(f"\n Feature: '{feature}': \n percentage of missing values is: {np.round(df[feature].isnull().mean()*100,4)}\n")
    print('*'*60)
# Out:
#  Feature: 'delivery_person_age':
#  percentage of missing values is: 4.0672
#
# ************************************************************
#
#  Feature: 'delivery_person_ratings':
#  percentage of missing values is: 4.1857
#
# ************************************************************
#
#  Feature: 'time_orderd':
#  percentage of missing values is: 3.7974
#
# ************************************************************
#
#  Feature: 'weather_conditions':
#  percentage of missing values is: 1.3514
#
# ************************************************************
#
#  Feature: 'road_traffic_density':
#  percentage of missing values is: 1.3184
#
# ************************************************************
#
#  Feature: 'multiple_deliveries':
#  percentage of missing values is: 2.1784
#
# ************************************************************
#
#  Feature: 'festival':
#  percentage of missing values is: 0.5002
#
# ************************************************************
#
#  Feature: 'city':
#  percentage of missing values is: 2.6325
#
# ************************************************************

# %% [markdown]
# # Plots

# %%
# Shpwing graphs with missing values representing '1'
data = df.copy()

for feature in features_with_na:
    
    data[feature] = np.where(data[feature].isnull(), 1,0 ) # where(condition, [x, y])
    data.groupby(feature)['time_taken_min'].median().plot.bar()
    
    plt.show()

# %%
df.head()
# Out:
#        id delivery_person_id  delivery_person_age  delivery_person_ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    restaurant_latitude  restaurant_longitude  delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    delivery_location_longitude  order_date time_orderd time_order_picked  \
# 0                    78.116106  12-02-2022       21:55             22:10
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
#
#   weather_conditions road_traffic_density  vehicle_condition type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   type_of_vehicle  multiple_deliveries festival           city  time_taken_min
# 0      motorcycle                  3.0       No  Metropolitian              46
# 1      motorcycle                  1.0       No  Metropolitian              23
# 2         scooter                  1.0       No  Metropolitian              21
# 3      motorcycle                  0.0       No  Metropolitian              20
# 4         scooter                  1.0       No  Metropolitian              41

# %%
df.delivery_person_age.sort_values() # 15 year delivery persons working no license --> lets consider as outliers
# Out:
# 2896     15.0
# 23479    15.0
# 33189    15.0
# 2942     15.0
# 9147     15.0
#          ...
# 45499     NaN
# 45509     NaN
# 45510     NaN
# 45517     NaN
# 45557     NaN
# Name: delivery_person_age, Length: 45584, dtype: float64

# %%
df.delivery_person_age.value_counts()
# Out:
# 35.0    2261
# 36.0    2260
# 30.0    2226
# 37.0    2226
# 38.0    2218
# 24.0    2210
# 32.0    2201
# 22.0    2194
# 29.0    2191
# 33.0    2186
# 28.0    2179
# 25.0    2174
# 34.0    2165
# 26.0    2159
# 21.0    2153
# 27.0    2150
# 39.0    2144
# 20.0    2136
# 31.0    2120
# 23.0    2086
# 50.0      53
# 15.0      38
# Name: delivery_person_age, dtype: int64

# %%
# df.loc[df['col1'] == value]
df.loc[df['delivery_person_age'] == na] # --> 38 values


# time_orderd                     0 -->  There is no order --> need to drop
# Out:
#   Input In [86]
#     df.loc[df['delivery_person_age'] == na] --> 38 values
#                                              ^
# SyntaxError: invalid syntax

# %%
df.loc[df['delivery_person_age'] == 15].count()
# Out:
# id                             38
# delivery_person_id             38
# delivery_person_age            38
# delivery_person_ratings        38
# restaurant_latitude            38
# restaurant_longitude           38
# delivery_location_latitude     38
# delivery_location_longitude    38
# order_date                     38
# time_orderd                     0
# time_order_picked              38
# weather_conditions              0
# road_traffic_density            0
# vehicle_condition              38
# type_of_order                  38
# type_of_vehicle                38
# multiple_deliveries            38
# festival                       38
# city                           38
# time_taken_min                 38
# dtype: int64

# %%
list(df.delivery_person_age.unique())
# Out:
# [36.0,
#  21.0,
#  23.0,
#  34.0,
#  24.0,
#  29.0,
#  35.0,
#  33.0,
#  25.0,
#  31.0,
#  37.0,
#  27.0,
#  32.0,
#  26.0,
#  38.0,
#  20.0,
#  22.0,
#  nan,
#  28.0,
#  39.0,
#  30.0,
#  15.0,
#  50.0]

# %%
df_copy = df.copy()

# %%
i = df_copy.loc[df_copy['delivery_person_age'] == 15].index 
# --> returned as list and can use in drop method with the list

i
# Out:
# Int64Index([ 2378,  2896,  2942,  5893,  9147, 10891, 11116, 12084, 15115,
#             15918, 16075, 16453, 21213, 22282, 23026, 23479, 23635, 23655,
#             25864, 26624, 26908, 27109, 27933, 27994, 29655, 31207, 31950,
#             33189, 34944, 36012, 37091, 37667, 39064, 39073, 40276, 41232,
#             44394, 44872],
#            dtype='int64')

# %%
df_copy.drop(i)
# Out:
#            id delivery_person_id  delivery_person_age  \
# 0      0xcdcd      DEHRES17DEL01                 36.0
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 0                          4.2            30.327968             78.046106
# 1                          4.7            10.003064             76.307589
# 2                          4.7            18.562450             73.916619
# 3                          4.3            30.899584             75.809346
# 4                          4.7            26.463504             80.372929
# ...                        ...                  ...                   ...
# 45579                      4.8            26.902328             75.794257
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        delivery_location_latitude  delivery_location_longitude  order_date  \
# 0                       30.397968                    78.116106  12-02-2022
# 1                       10.043064                    76.347589  13-02-2022
# 2                       18.652450                    74.006619  04-03-2022
# 3                       30.919584                    75.829346  13-02-2022
# 4                       26.593504                    80.502929  14-02-2022
# ...                           ...                          ...         ...
# 45579                   26.912328                    75.804257  24-03-2022
# 45580                    0.070000                     0.070000  16-02-2022
# 45581                   13.052394                    80.272439  11-03-2022
# 45582                   11.041753                    77.026241  07-03-2022
# 45583                   23.431058                    85.405731  02-03-2022
#
#       time_orderd time_order_picked weather_conditions road_traffic_density  \
# 0           21:55             22:10                Fog                  Jam
# 1           14:55             15:05             Stormy                 High
# 2           17:30             17:40         Sandstorms               Medium
# 3           09:20             09:30         Sandstorms                  Low
# 4           19:50             20:05                Fog                  Jam
# ...           ...               ...                ...                  ...
# 45579       11:35             11:45              Windy                 High
# 45580       19:55             20:10              Windy                  Jam
# 45581       23:50          24:05:00             Cloudy                  Low
# 45582       13:35             13:40             Cloudy                 High
# 45583       17:10             17:15                Fog               Medium
#
#        vehicle_condition type_of_order type_of_vehicle  multiple_deliveries  \
# 0                      2         Snack      motorcycle                  3.0
# 1                      1          Meal      motorcycle                  1.0
# 2                      1        Drinks         scooter                  1.0
# 3                      0        Buffet      motorcycle                  0.0
# 4                      1         Snack         scooter                  1.0
# ...                  ...           ...             ...                  ...
# 45579                  1          Meal      motorcycle                  0.0
# 45580                  0        Buffet      motorcycle                  1.0
# 45581                  1        Drinks         scooter                  0.0
# 45582                  0         Snack      motorcycle                  1.0
# 45583                  2         Snack         scooter                  1.0
#
#       festival           city  time_taken_min
# 0           No  Metropolitian              46
# 1           No  Metropolitian              23
# 2           No  Metropolitian              21
# 3           No  Metropolitian              20
# 4           No  Metropolitian              41
# ...        ...            ...             ...
# 45579       No  Metropolitian              32
# 45580       No  Metropolitian              36
# 45581       No  Metropolitian              16
# 45582       No  Metropolitian              26
# 45583       No  Metropolitian              36
#
# [45546 rows x 20 columns]

# %%
df_copy.loc[df_copy['delivery_person_age'] == 15]
# Out:
#            id delivery_person_id  delivery_person_age  \
# 2378    0x564      JAPRES15DEL03                 15.0
# 2896    0xcd0    INDORES010DEL03                 15.0
# 2942    0x91a      SURRES17DEL03                 15.0
# 5893    0x474     CHENRES15DEL03                 15.0
# 9147    0x73f     BANGRES05DEL01                 15.0
# 10891  0x1b49      MUMRES14DEL02                 15.0
# 11116   0x40b      SURRES12DEL01                 15.0
# 12084   0x523     INDORES03DEL02                 15.0
# 15115  0x18b0   RANCHIRES02DEL01                 15.0
# 15918   0x550     CHENRES08DEL02                 15.0
# 16075   0x58c      MUMRES02DEL01                 15.0
# 16453   0xe4c      MYSRES05DEL03                 15.0
# 21213   0x3fc     BANGRES16DEL02                 15.0
# 22282   0x3ed   RANCHIRES09DEL01                 15.0
# 23026   0x415      VADRES17DEL01                 15.0
# 23479  0x616c      SURRES07DEL02                 15.0
# 23635  0x1ea0     BANGRES17DEL02                 15.0
# 23655   0x3f7     CHENRES04DEL01                 15.0
# 25864   0xbb3     CHENRES15DEL03                 15.0
# 26624   0x730     INDORES15DEL02                 15.0
# 26908   0x6e0     CHENRES06DEL03                 15.0
# 27109   0x3f2     BANGRES02DEL02                 15.0
# 27933   0x681     CHENRES07DEL03                 15.0
# 27994   0x406     PUNERES14DEL01                 15.0
# 29655  0x137e      MYSRES19DEL02                 15.0
# 31207  0x32aa      JAPRES11DEL01                 15.0
# 31950  0x4240     PUNERES05DEL02                 15.0
# 33189   0x622     CHENRES03DEL02                 15.0
# 34944   0x85c    COIMBRES17DEL02                 15.0
# 36012   0xdc0    COIMBRES03DEL03                 15.0
# 37091   0x451      HYDRES14DEL03                 15.0
# 37667   0x424     PUNERES20DEL02                 15.0
# 39064   0x4a6    COIMBRES07DEL02                 15.0
# 39073  0x1144      MYSRES05DEL01                 15.0
# 40276   0x442     CHENRES16DEL02                 15.0
# 41232   0x49c    COIMBRES14DEL02                 15.0
# 44394  0x2314      VADRES04DEL01                 15.0
# 44872   0x8d4     CHENRES02DEL02                 15.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
#
# 26624                  3         Snack  electric_scooter                  1.0
# 26908                  3          Meal  electric_scooter                  1.0
# 27109                  3        Drinks  electric_scooter                  0.0
# 27933                  3        Buffet  electric_scooter                  1.0
# 27994                  3        Buffet           scooter                  1.0
# 29655                  3        Drinks           scooter                  1.0
# 31207                  3         Snack  electric_scooter                  1.0
# 31950                  3          Meal           bicycle                  0.0
# 33189                  3        Buffet           scooter                  0.0
# 34944                  3         Snack           scooter                  1.0
# 36012                  3          Meal        motorcycle                  1.0
# 37091                  3        Buffet  electric_scooter                  1.0
# 37667                  3        Buffet           scooter                  1.0
# 39064                  3        Drinks  electric_scooter                  0.0
# 39073                  3         Snack  electric_scooter                  0.0
# 40276                  3         Snack           bicycle                  0.0
# 41232                  3          Meal           scooter                  0.0
# 44394                  3        Drinks           scooter                  0.0
# 44872                  3         Snack  electric_scooter                  1.0
#
#       festival           city  time_taken_min
# 2378        No          Urban              15
# 2896        No  Metropolitian              29
# 2942        No  Metropolitian              20
# 5893        No  Metropolitian              25
# 9147        No  Metropolitian              34
# 10891       No  Metropolitian              39
# 11116       No          Urban              27
# 12084       No  Metropolitian              28
# 15115       No  Metropolitian              21
# 15918       No  Metropolitian              17
# 16075       No  Metropolitian              23
# 16453       No          Urban              24
# 21213       No  Metropolitian              28
# 22282      Yes  Metropolitian              44
# 23026       No          Urban              27
# 23479       No  Metropolitian              32
# 23635       No  Metropolitian              23
# 23655       No          Urban              15
# 25864       No  Metropolitian              27
# 26624       No  Metropolitian              27
# 26908       No          Urban              21
# 27109       No          Urban              20
# 27933       No  Metropolitian              27
# 27994       No  Metropolitian              38
# 29655       No  Metropolitian              13
# 31207       No          Urban              19
# 31950       No  Metropolitian              21
# 33189       No  Metropolitian              33
# 34944       No  Metropolitian              19
# 36012       No  Metropolitian              28
# 37091       No          Urban              30
# 37667       No          Urban              30
# 39064       No  Metropolitian              24
# 39073       No  Metropolitian              30
# 40276       No  Metropolitian              25
# 41232       No  Metropolitian              25
# 44394       No  Metropolitian              34
# 44872       No          Urban              26

# %%
df_copy.drop(i, inplace=True)

# %%
df_copy.loc[df_copy['delivery_person_age'] == 15]
# Out:
# Empty DataFrame
# Columns: [id, delivery_person_id, delivery_person_age, delivery_person_ratings, restaurant_latitude, restaurant_longitude, delivery_location_latitude, delivery_location_longitude, order_date, time_orderd, time_order_picked, weather_conditions, road_traffic_density, vehicle_condition, type_of_order, type_of_vehicle, multiple_deliveries, festival, city, time_taken_min]
# Index: []

# %%
df_copy.delivery_person_age.unique()
# Out:
# array([36., 21., 23., 34., 24., 29., 35., 33., 25., 31., 37., 27., 32.,
#        26., 38., 20., 22., nan, 28., 39., 30., 50.])

# %%
df_copy['delivery_person_age'].dtype
# Out:
# dtype('float64')

# %%
df_copy['delivery_person_ratings'].unique() # --> 6 rating
# Out:
# array([4.2, 4.7, 4.3, 4.5, 4. , 4.9, 4.1, 5. , 4.8, 3.5, 4.6, nan, 4.4,
#        3.8, 3.9, 3.7, 2.6, 2.5, 3.6, 3.1, 2.7, 3.2, 3.3, 6. , 3.4, 2.8,
#        2.9, 3. ])

# %%
df_copy.loc[df_copy['delivery_person_ratings'] == 6] 
# -->  no orders placed and ratings are 6 considering ratings on basis 5 and age is 50
# Out:
#            id delivery_person_id  delivery_person_age  \
# 3577    0x46d     BANGRES05DEL01                 50.0
# 4705    0x493      HYDRES17DEL01                 50.0
# 5160    0x4f2      JAPRES08DEL01                 50.0
# 5353    0x430     BANGRES19DEL01                 50.0
# 5642   0xbef1      AGRRES13DEL02                 50.0
# 6385    0x427      JAPRES06DEL02                 50.0
# 7022    0x3eb      MYSRES15DEL02                 50.0
# 7672    0xd42      VADRES09DEL01                 50.0
# 9490    0x3f0    BANGRES010DEL01                 50.0
# 9526    0x3ef   RANCHIRES13DEL01                 50.0
# 10091   0x5b0      MYSRES04DEL01                 50.0
# 10728  0xbffc      DEHRES18DEL02                 50.0
# 12288   0x940      SURRES02DEL02                 50.0
# 13248   0x490    COIMBRES03DEL02                 50.0
# 13643   0x434   RANCHIRES01DEL02                 50.0
# 14097   0x3f6      MYSRES06DEL02                 50.0
# 14898   0x421     CHENRES19DEL01                 50.0
# 14935   0x43c      HYDRES14DEL01                 50.0
# 16789   0x3fa   RANCHIRES06DEL02                 50.0
# 17136   0x400    COIMBRES07DEL01                 50.0
# 17699   0x412    CHENRES010DEL01                 50.0
# 18968  0xc363      BHPRES08DEL03                 50.0
# 19373   0x3fb     INDORES02DEL03                 50.0
# 20260  0xd0bc      ALHRES01DEL02                 50.0
# 21311   0x810      HYDRES06DEL01                 50.0
# 22407  0xc7d6      ALHRES08DEL03                 50.0
# 23366  0x1060     BANGRES05DEL03                 50.0
# 24228   0x420      SURRES13DEL01                 50.0
# 24909  0xbf34      KNPRES16DEL02                 50.0
# 25276   0x40c    COIMBRES08DEL03                 50.0
# 26043   0x694   RANCHIRES09DEL02                 50.0
# 27212   0x3f4    COIMBRES20DEL02                 50.0
# 27390   0x3ea      MUMRES20DEL03                 50.0
# 28306   0x3fd     BANGRES13DEL01                 50.0
# 28965   0x404     CHENRES04DEL01                 50.0
# 29526   0x480     BANGRES15DEL01                 50.0
# 30570  0xbf12      BHPRES20DEL03                 50.0
# 30934   0x4cc      MUMRES20DEL01                 50.0
# 31224   0x706      VADRES09DEL02                 50.0
# 32317  0xbf33      KNPRES03DEL03                 50.0
# 33524  0xbf01      KOLRES06DEL02                 50.0
# 34679  0xbf76      AGRRES20DEL03                 50.0
# 37998  0xbef2      DEHRES13DEL01                 50.0
# 38011   0x466     CHENRES14DEL02                 50.0
# 38552   0x3f1      VADRES09DEL03                 50.0
# 38640   0x5e0      MUMRES07DEL03                 50.0
# 39690   0xa24   RANCHIRES14DEL03                 50.0
# 40214   0x3e9      MYSRES04DEL03                 50.0
# 41096   0x4e4      VADRES17DEL01                 50.0
# 41960  0xbef4      KNPRES19DEL03                 50.0
# 42063   0x5fc     INDORES11DEL03                 50.0
# 42826   0x53e     BANGRES12DEL01                 50.0
# 45323  0x2950      VADRES04DEL02                 50.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
#
# 41960                  3        Drinks           scooter                  1.0
# 42063                  3        Buffet           scooter                  0.0
# 42826                  3        Drinks  electric_scooter                  1.0
# 45323                  3        Drinks  electric_scooter                  1.0
#
#       festival           city  time_taken_min
# 3577        No          Urban              25
# 4705        No  Metropolitian              27
# 5160        No  Metropolitian              20
# 5353        No  Metropolitian              18
# 5642        No  Metropolitian              20
# 6385        No          Urban              20
# 7022        No  Metropolitian              14
# 7672        No  Metropolitian              22
# 9490        No          Urban              17
# 9526        No  Metropolitian              32
# 10091       No  Metropolitian              35
# 10728       No  Metropolitian              25
# 12288       No          Urban              22
# 13248       No          Urban              11
# 13643       No  Metropolitian              28
# 14097       No          Urban              15
# 14898       No  Metropolitian              12
# 14935       No          Urban              19
# 16789       No  Metropolitian              22
# 17136       No          Urban              14
# 17699       No  Metropolitian              20
# 18968       No  Metropolitian              17
# 19373       No  Metropolitian              30
# 20260       No          Urban              33
# 21311       No  Metropolitian              35
# 22407       No  Metropolitian              29
# 23366       No          Urban              19
# 24228       No  Metropolitian              17
# 24909       No  Metropolitian              41
# 25276       No  Metropolitian              16
# 26043       No  Metropolitian              20
# 27212       No            NaN              17
# 27390       No  Metropolitian              18
# 28306       No  Metropolitian              28
# 28965       No  Metropolitian              20
# 29526       No  Metropolitian              15
# 30570       No  Metropolitian              39
# 30934       No          Urban              30
# 31224       No  Metropolitian              28
# 32317       No            NaN              17
# 33524       No  Metropolitian              28
# 34679       No          Urban              16
# 37998       No  Metropolitian              25
# 38011       No  Metropolitian              14
# 38552       No  Metropolitian              36
# 38640       No          Urban              26
# 39690       No  Metropolitian              39
# 40214       No  Metropolitian              40
# 41096      Yes  Metropolitian              48
# 41960       No  Metropolitian              15
# 42063       No  Metropolitian              28
# 42826       No  Metropolitian              19
# 45323       No          Urban              28

# %%
print(df_copy.loc[df_copy['delivery_person_ratings'] == 6].count())
# Out:
# id                             53
# delivery_person_id             53
# delivery_person_age            53
# delivery_person_ratings        53
# restaurant_latitude            53
# restaurant_longitude           53
# delivery_location_latitude     53
# delivery_location_longitude    53
# order_date                     53
# time_orderd                     0
# time_order_picked              53
# weather_conditions              0
# road_traffic_density            0
# vehicle_condition              53
# type_of_order                  53
# type_of_vehicle                53
# multiple_deliveries            53
# festival                       53
# city                           51
# time_taken_min                 53
# dtype: int64

# %%
i = df_copy.loc[df_copy['delivery_person_ratings'] == 6].index 
# --> returned as list and can use in drop method with the list

i
# Out:
# Int64Index([ 3577,  4705,  5160,  5353,  5642,  6385,  7022,  7672,  9490,
#              9526, 10091, 10728, 12288, 13248, 13643, 14097, 14898, 14935,
#             16789, 17136, 17699, 18968, 19373, 20260, 21311, 22407, 23366,
#             24228, 24909, 25276, 26043, 27212, 27390, 28306, 28965, 29526,
#             30570, 30934, 31224, 32317, 33524, 34679, 37998, 38011, 38552,
#             38640, 39690, 40214, 41096, 41960, 42063, 42826, 45323],
#            dtype='int64')

# %%
df_copy.drop(i)
# Out:
#            id delivery_person_id  delivery_person_age  \
# 0      0xcdcd      DEHRES17DEL01                 36.0
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 0                          4.2            30.327968             78.046106
# 1                          4.7            10.003064             76.307589
# 2                          4.7            18.562450             73.916619
# 3                          4.3            30.899584             75.809346
# 4                          4.7            26.463504             80.372929
# ...                        ...                  ...                   ...
# 45579                      4.8            26.902328             75.794257
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        delivery_location_latitude  delivery_location_longitude  order_date  \
# 0                       30.397968                    78.116106  12-02-2022
# 1                       10.043064                    76.347589  13-02-2022
# 2                       18.652450                    74.006619  04-03-2022
# 3                       30.919584                    75.829346  13-02-2022
# 4                       26.593504                    80.502929  14-02-2022
# ...                           ...                          ...         ...
# 45579                   26.912328                    75.804257  24-03-2022
# 45580                    0.070000                     0.070000  16-02-2022
# 45581                   13.052394                    80.272439  11-03-2022
# 45582                   11.041753                    77.026241  07-03-2022
# 45583                   23.431058                    85.405731  02-03-2022
#
#       time_orderd time_order_picked weather_conditions road_traffic_density  \
# 0           21:55             22:10                Fog                  Jam
# 1           14:55             15:05             Stormy                 High
# 2           17:30             17:40         Sandstorms               Medium
# 3           09:20             09:30         Sandstorms                  Low
# 4           19:50             20:05                Fog                  Jam
# ...           ...               ...                ...                  ...
# 45579       11:35             11:45              Windy                 High
# 45580       19:55             20:10              Windy                  Jam
# 45581       23:50          24:05:00             Cloudy                  Low
# 45582       13:35             13:40             Cloudy                 High
# 45583       17:10             17:15                Fog               Medium
#
#        vehicle_condition type_of_order type_of_vehicle  multiple_deliveries  \
# 0                      2         Snack      motorcycle                  3.0
# 1                      1          Meal      motorcycle                  1.0
# 2                      1        Drinks         scooter                  1.0
# 3                      0        Buffet      motorcycle                  0.0
# 4                      1         Snack         scooter                  1.0
# ...                  ...           ...             ...                  ...
# 45579                  1          Meal      motorcycle                  0.0
# 45580                  0        Buffet      motorcycle                  1.0
# 45581                  1        Drinks         scooter                  0.0
# 45582                  0         Snack      motorcycle                  1.0
# 45583                  2         Snack         scooter                  1.0
#
#       festival           city  time_taken_min
# 0           No  Metropolitian              46
# 1           No  Metropolitian              23
# 2           No  Metropolitian              21
# 3           No  Metropolitian              20
# 4           No  Metropolitian              41
# ...        ...            ...             ...
# 45579       No  Metropolitian              32
# 45580       No  Metropolitian              36
# 45581       No  Metropolitian              16
# 45582       No  Metropolitian              26
# 45583       No  Metropolitian              36
#
# [45493 rows x 20 columns]

# %%
df_copy.loc[df_copy['delivery_person_ratings'] == 6]
# Out:
#            id delivery_person_id  delivery_person_age  \
# 3577    0x46d     BANGRES05DEL01                 50.0
# 4705    0x493      HYDRES17DEL01                 50.0
# 5160    0x4f2      JAPRES08DEL01                 50.0
# 5353    0x430     BANGRES19DEL01                 50.0
# 5642   0xbef1      AGRRES13DEL02                 50.0
# 6385    0x427      JAPRES06DEL02                 50.0
# 7022    0x3eb      MYSRES15DEL02                 50.0
# 7672    0xd42      VADRES09DEL01                 50.0
# 9490    0x3f0    BANGRES010DEL01                 50.0
# 9526    0x3ef   RANCHIRES13DEL01                 50.0
# 10091   0x5b0      MYSRES04DEL01                 50.0
# 10728  0xbffc      DEHRES18DEL02                 50.0
# 12288   0x940      SURRES02DEL02                 50.0
# 13248   0x490    COIMBRES03DEL02                 50.0
# 13643   0x434   RANCHIRES01DEL02                 50.0
# 14097   0x3f6      MYSRES06DEL02                 50.0
# 14898   0x421     CHENRES19DEL01                 50.0
# 14935   0x43c      HYDRES14DEL01                 50.0
# 16789   0x3fa   RANCHIRES06DEL02                 50.0
# 17136   0x400    COIMBRES07DEL01                 50.0
# 17699   0x412    CHENRES010DEL01                 50.0
# 18968  0xc363      BHPRES08DEL03                 50.0
# 19373   0x3fb     INDORES02DEL03                 50.0
# 20260  0xd0bc      ALHRES01DEL02                 50.0
# 21311   0x810      HYDRES06DEL01                 50.0
# 22407  0xc7d6      ALHRES08DEL03                 50.0
# 23366  0x1060     BANGRES05DEL03                 50.0
# 24228   0x420      SURRES13DEL01                 50.0
# 24909  0xbf34      KNPRES16DEL02                 50.0
# 25276   0x40c    COIMBRES08DEL03                 50.0
# 26043   0x694   RANCHIRES09DEL02                 50.0
# 27212   0x3f4    COIMBRES20DEL02                 50.0
# 27390   0x3ea      MUMRES20DEL03                 50.0
# 28306   0x3fd     BANGRES13DEL01                 50.0
# 28965   0x404     CHENRES04DEL01                 50.0
# 29526   0x480     BANGRES15DEL01                 50.0
# 30570  0xbf12      BHPRES20DEL03                 50.0
# 30934   0x4cc      MUMRES20DEL01                 50.0
# 31224   0x706      VADRES09DEL02                 50.0
# 32317  0xbf33      KNPRES03DEL03                 50.0
# 27390                  3          Meal  electric_scooter                  1.0
# 28306                  3        Drinks  electric_scooter                  0.0
# 28965                  3          Meal  electric_scooter                  0.0
# 29526                  3        Drinks  electric_scooter                  1.0
# 30570                  3         Snack           bicycle                  2.0
# 30934                  3          Meal           scooter                  1.0
# 31224                  3        Drinks           scooter                  0.0
# 32317                  3        Drinks           scooter                  0.0
# 33524                  3         Snack           scooter                  1.0
# 34679                  3        Drinks  electric_scooter                  1.0
# 37998                  3         Snack  electric_scooter                  1.0
# 38011                  3          Meal           scooter                  0.0
# 38552                  3        Drinks  electric_scooter                  0.0
# 38640                  3        Buffet  electric_scooter                  1.0
# 39690                  3        Buffet           bicycle                  1.0
# 40214                  3        Drinks  electric_scooter                  1.0
# 41096                  3          Meal           scooter                  1.0
# 41960                  3        Drinks           scooter                  1.0
# 42063                  3        Buffet           scooter                  0.0
# 42826                  3        Drinks  electric_scooter                  1.0
# 45323                  3        Drinks  electric_scooter                  1.0
#
#       festival           city  time_taken_min
# 3577        No          Urban              25
# 4705        No  Metropolitian              27
# 5160        No  Metropolitian              20
# 5353        No  Metropolitian              18
# 5642        No  Metropolitian              20
# 6385        No          Urban              20
# 7022        No  Metropolitian              14
# 7672        No  Metropolitian              22
# 9490        No          Urban              17
# 9526        No  Metropolitian              32
# 10091       No  Metropolitian              35
# 10728       No  Metropolitian              25
# 12288       No          Urban              22
# 13248       No          Urban              11
# 13643       No  Metropolitian              28
# 14097       No          Urban              15
# 14898       No  Metropolitian              12
# 14935       No          Urban              19
# 16789       No  Metropolitian              22
# 17136       No          Urban              14
# 17699       No  Metropolitian              20
# 18968       No  Metropolitian              17
# 19373       No  Metropolitian              30
# 20260       No          Urban              33
# 21311       No  Metropolitian              35
# 22407       No  Metropolitian              29
# 23366       No          Urban              19
# 24228       No  Metropolitian              17
# 24909       No  Metropolitian              41
# 25276       No  Metropolitian              16
# 26043       No  Metropolitian              20
# 27212       No            NaN              17
# 27390       No  Metropolitian              18
# 28306       No  Metropolitian              28
# 28965       No  Metropolitian              20
# 29526       No  Metropolitian              15
# 30570       No  Metropolitian              39
# 30934       No          Urban              30
# 31224       No  Metropolitian              28
# 32317       No            NaN              17
# 33524       No  Metropolitian              28
# 34679       No          Urban              16
# 37998       No  Metropolitian              25
# 38011       No  Metropolitian              14
# 38552       No  Metropolitian              36
# 38640       No          Urban              26
# 39690       No  Metropolitian              39
# 40214       No  Metropolitian              40
# 41096      Yes  Metropolitian              48
# 41960       No  Metropolitian              15
# 42063       No  Metropolitian              28
# 42826       No  Metropolitian              19
# 45323       No          Urban              28

# %%
df_copy['delivery_person_ratings'].unique()
# Out:
# array([4.2, 4.7, 4.3, 4.5, 4. , 4.9, 4.1, 5. , 4.8, 3.5, 4.6, nan, 4.4,
#        3.8, 3.9, 3.7, 2.6, 2.5, 3.6, 3.1, 2.7, 3.2, 3.3, 3.4, 2.8, 2.9,
#        3. ])

# %%
df_copy.drop(i,inplace=True)

# %%
df_copy.loc[df_copy['delivery_person_ratings'] == 6]
# Out:
# Empty DataFrame
# Columns: [id, delivery_person_id, delivery_person_age, delivery_person_ratings, restaurant_latitude, restaurant_longitude, delivery_location_latitude, delivery_location_longitude, order_date, time_orderd, time_order_picked, weather_conditions, road_traffic_density, vehicle_condition, type_of_order, type_of_vehicle, multiple_deliveries, festival, city, time_taken_min]
# Index: []

# %%
df_copy.sample(5)
# Out:
#            id delivery_person_id  delivery_person_age  \
# 21955  0x5814      HYDRES02DEL03                 20.0
# 25510  0x58b7      SURRES11DEL01                 35.0
# 38775  0x82c7     INDORES14DEL01                 35.0
# 19139  0x14c6    COIMBRES11DEL02                 36.0
# 14975  0xc55d      BHPRES13DEL02                 34.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 21955                      4.9            17.412330             78.449654
# 25510                      4.0            21.157735             72.768778
# 38775                      4.8            22.761593             75.886362
# 19139                      4.6            11.001753             76.986241
# 14975                      4.2            23.230791             77.437020
#
#        delivery_location_latitude  delivery_location_longitude  order_date  \
# 21955                   17.472330                    78.509654  05-03-2022
# 25510                   21.227735                    72.838778  06-04-2022
# 38775                   22.771593                    75.896362  13-03-2022
# 19139                   11.021753                    77.006241  26-03-2022
# 14975                   23.310791                    77.517020  14-02-2022
#
#       time_orderd time_order_picked weather_conditions road_traffic_density  \
# 21955       21:20             21:35             Stormy                  Jam
# 25510       20:15             20:25             Cloudy                  Jam
# 38775       09:50       0.416666667                Fog                  Low
# 19139       08:45             08:55              Windy                  Low
# 14975       21:30             21:40                Fog                  Jam
#
#        vehicle_condition type_of_order   type_of_vehicle  multiple_deliveries  \
# 21955                  2        Buffet           scooter                  0.0
# 25510                  2         Snack  electric_scooter                  0.0
# 38775                  2          Meal  electric_scooter                  1.0
# 19139                  2          Meal  electric_scooter                  1.0
# 14975                  2        Drinks           scooter                  1.0
#
#       festival           city  time_taken_min
# 21955       No          Urban              14
# 25510       No  Metropolitian              39
# 38775       No  Metropolitian              18
# 19139       No  Metropolitian              26
# 14975       No  Metropolitian              48

# %%
df_copy['delivery_person_ratings'].dtype
# Out:
# dtype('float64')

# %% [markdown]
#  ## ordered date and time

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45493 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           45493 non-null  object
#  1   delivery_person_id           45493 non-null  object
#  2   delivery_person_age          43639 non-null  float64
#  3   delivery_person_ratings      43585 non-null  float64
#  4   restaurant_latitude          45493 non-null  float64
#  5   restaurant_longitude         45493 non-null  float64
#  6   delivery_location_latitude   45493 non-null  float64
#  7   delivery_location_longitude  45493 non-null  float64
#  8   order_date                   45493 non-null  object
#  9   time_orderd                  43853 non-null  object
#  10  time_order_picked            45493 non-null  object
#  11  weather_conditions           44968 non-null  object
#  12  road_traffic_density         44983 non-null  object
#  13  vehicle_condition            45493 non-null  int64
#  14  type_of_order                45493 non-null  object
#  15  type_of_vehicle              45493 non-null  object
#  16  multiple_deliveries          44500 non-null  float64
#  17  festival                     45265 non-null  object
#  18  city                         44295 non-null  object
#  19  time_taken_min               45493 non-null  int64
# dtypes: float64(7), int64(2), object(11)
# memory usage:
#        '22:25', '20:55', '23:05', '0.75', '0.958333333', '09:40', '20:20',
#        '22:35', '0.916666667', '23:55', '15:40', '10:30', '0.875',
#        '10:50', '16:05', '20:15', '12:15', '15:45', '22:15', '10:45',
#        '15:30', '24:05:00', '21:25', '12:45', '21:15', '18:20', '18:25',
#        '11:50', '12:50', '10:55', '21:40', '10:20', '17:55', '23:50',
#        '12:55', '24:10:00', '10:40', '0.375', '20:45', '0.833333333',
#        '23:15', '22:20', '21:05', '0.708333333', '24:15:00', '21:20',
#        '14:35', '10:25', '09:05', '16:50', '08:40', '23:40', '21:50',
#        '19:55', '0.625', '10:35', '09:25', '17:20', '19:30', '17:25',
#        '20:10', '1', '17:35', '0.791666667', '19:05', '13:20', '17:50',
#        '18:05', '19:20', '10:05', '09:10', '21:55', '19:40', '18:10',
#        '09:50', '15:50', '18:30', '18:15', '16:15', '11:15', '21:10',
#        '22:30', '15:20', '18:40', '23:20', '11:25', '13:55', '18:45',
#        '22:05', '11:55', '18:55', '09:45', '17:15', '12:05', '0.5',
#        '19:35', '08:25', '11:05', '15:35', '12:40', '12:25', '08:20',
#        '23:25', '16:10', '13:45', '08:15', '08:45', '20:30',
#        '0.541666667', '11:20', '08:50', '14:45', '17:45', '0.416666667',
#        '08:35', '12:10', '11:35', '14:30', '10:15', '17:05', '10:10',
#        '09:35', '11:30', '16:25', '09:15', '13:35', '15:55', '13:10',
#        '13:05', '11:45', '16:20', '16:30', '16:45', '09:20', '13:25',
#        '14:15', '14:05', '16:35', '16:40', '13:30', '14:40', '12:20',
#        '13:50', '17:10', '15:25', '14:20', '12:35', '0.583333333',
#        '14:10', '14:55', '13:15', '14:50', '0.666666667'], dtype=object)

# %%
df_copy.shape
# Out:
# (45493, 20)

# %%
# pattern match time format are kept and others are dropped


df_copy = df_copy[~((~df_copy.time_orderd.str.contains(r'[0-9]{2}:[0-9]{2}', na = False)) | (~df_copy.time_order_picked.str.contains(r'[0-9]{2}:[0-9]{2}', na=False)))]

# %%
df_copy.shape # 45493 - 35818 = 7675 rows are dropped
# Out:
# (35818, 20)

# %%
df_copy.time_order_picked.unique()
# Out:
# array(['22:10', '15:05', '17:40', '09:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '08:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '09:55', '08:55',
#        '17:30', '19:50', '19:25', '16:55', '11:40', '15:15', '22:55',
#        '22:25', '20:55', '23:05', '09:40', '20:20', '22:35', '23:55',
#        '15:40', '10:30', '10:50', '16:05', '20:15', '12:15', '15:45',
#        '22:15', '10:45', '24:05:00', '21:25', '12:45', '18:20', '18:25',
#        '11:50', '12:50', '10:55', '21:40', '10:20', '17:55', '23:50',
#        '12:55', '24:10:00', '10:40', '11:10', '20:45', '23:15', '18:35',
#        '22:20', '21:05', '21:20', '14:35', '10:25', '16:50', '08:40',
#        '23:40', '21:50', '19:55', '10:35', '09:25', '17:20', '19:30',
# 316    0x26d4      HYDRES05DEL03                 32.0
# 559     0xaea     BANGRES19DEL01                 23.0
# 566    0x5fd4      SURRES04DEL01                 23.0
# ...       ...                ...                  ...
# 44839  0xdefc      KOLRES19DEL02                 28.0
# 45077  0x5ae6      MUMRES01DEL01                 27.0
# 45352  0x6a9b      SURRES16DEL01                 26.0
# 45520  0x1889      HYDRES01DEL02                 26.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 66                         4.7            17.431477             78.400350
# 92                         4.8            17.458998             78.500366
# 316                        4.9            17.433809             78.386744
# 559                        5.0            12.914264             77.678400
# 566                        2.5            21.173493             72.801953
# ...                        ...                  ...                   ...
# 44839                      4.8            22.549100             88.400467
# 45077                      4.7            19.126630             72.829976
# 45352                      4.9            21.160437             72.774209
# 45520                      4.5            17.410371             78.437225
# 45581                      4.9            13.022394             80.242439
#
#        delivery_location_latitude  delivery_location_longitude  order_date  \
# 66                      17.491477                    78.460350  05-03-2022
# 92                      17.488998                    78.530366  26-03-2022
# 316                     17.523809                    78.476744  18-03-2022
# 559                     13.024264                    77.788400  23-03-2022
# 566                     21.283493                    72.911953  20-03-2022
# ...                           ...                          ...         ...
# 44839                   22.679100                    88.530467  16-02-2022
# 45077                   19.196630                    72.899976  23-03-2022
# 45352                   21.270437                    72.884209  31-03-2022
# 45520                   17.540371                    78.567225  25-03-2022
# 45581                   13.052394                    80.272439  11-03-2022
#
#       time_orderd time_order_picked weather_conditions road_traffic_density  \
# 66          23:50          24:05:00                Fog                  Low
# 92          23:55          24:10:00             Cloudy                  Low
# 316         23:55          24:10:00         Sandstorms                  Low
# 559         23:55          24:05:00         Sandstorms                  Low
# 566         23:50          24:05:00              Sunny                  Low
# ...           ...               ...                ...                  ...
# 44839       23:55          24:10:00             Cloudy                  Low
# 45077       23:50          24:05:00             Stormy                  Low
# 45352       23:50          24:05:00             Cloudy                  Low
# 45520       23:50          24:05:00                Fog                  Low
# 45581       23:50          24:05:00             Cloudy                  Low
#
#        vehicle_condition type_of_order type_of_vehicle  multiple_deliveries  \
# 66                     1        Buffet      motorcycle                  0.0
# 92                     1         Snack         scooter                  1.0
# 316                    1        Buffet         scooter                  1.0
# 559                    1          Meal         scooter                  1.0
# 566                    1        Buffet      motorcycle                  1.0
# ...                  ...           ...             ...                  ...
# 44839                  1         Snack      motorcycle                  0.0
# 45077                  1        Drinks      motorcycle                  1.0
# 45352                  0         Snack      motorcycle                  0.0
# 45520                  0        Buffet      motorcycle                  0.0
# 45581                  1        Drinks         scooter                  0.0
#
#       festival           city  time_taken_min
# 66          No  Metropolitian              10
# 92          No          Urban              19
# 316         No  Metropolitian              24
# 559         No          Urban              11
# 566         No  Metropolitian              34
# ...        ...            ...             ...
# 44839       No          Urban              25
# 45077       No          Urban              14
# 45352       No  Metropolitian              21
# 45520       No  Metropolitian              24
# 45581       No  Metropolitian              16
#
# [411 rows x 20 columns]

# %%
#  24:05:00 format --> no values
df_copy[~((~df_copy.time_orderd.str.contains(r'[0-9]{2}:[0-9]{2}:[0-9]{2}', na = False)))]
# Out:
# Empty DataFrame
# Columns: [id, delivery_person_id, delivery_person_age, delivery_person_ratings, restaurant_latitude, restaurant_longitude, delivery_location_latitude, delivery_location_longitude, order_date, time_orderd, time_order_picked, weather_conditions, road_traffic_density, vehicle_condition, type_of_order, type_of_vehicle, multiple_deliveries, festival, city, time_taken_min]
# Index: []

# %%
df_time = pd.DataFrame(df_copy[['time_orderd','time_order_picked']])
df_time.tail(5)
# Out:
#       time_orderd time_order_picked
# 45579       11:35             11:45
# 45580       19:55             20:10
# 45581       23:50          24:05:00
# 45582       13:35             13:40
# 45583       17:10             17:15

# %%
df_copy.time_orderd.str.contains('24').sum()
# Out:
# 0

# %%
df_copy.time_order_picked.str.contains('24').sum()
# Out:
# 411

# %%
df_copy['time_order_picked'] = df_copy.time_order_picked.str.replace('24','00')
df_copy.tail()
# Out:
#            id delivery_person_id  delivery_person_age  \
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 45579                      4.8            26.902328             75.794257
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        delivery_location_latitude  delivery_location_longitude  order_date  \
# 45579                   26.912328                    75.804257  24-03-2022
# 45580                    0.070000                     0.070000  16-02-2022
# 45581                   13.052394                    80.272439  11-03-2022
# 45582                   11.041753                    77.026241  07-03-2022
# 45583                   23.431058                    85.405731  02-03-2022
#
#       time_orderd time_order_picked weather_conditions road_traffic_density  \
# 45579       11:35             11:45              Windy                 High
# 45580       19:55             20:10              Windy                  Jam
# 45581       23:50          00:05:00             Cloudy                  Low
# 45582       13:35             13:40             Cloudy                 High
# 45583       17:10             17:15                Fog               Medium
#
#        vehicle_condition type_of_order type_of_vehicle  multiple_deliveries  \
# 45579                  1          Meal      motorcycle                  0.0
# 45580                  0        Buffet      motorcycle                  1.0
# 45581                  1        Drinks         scooter                  0.0
# 45582                  0         Snack      motorcycle                  1.0
# 45583                  2         Snack         scooter                  1.0
#
#       festival           city  time_taken_min
# 45579       No  Metropolitian              32
# 45580       No  Metropolitian              36
# 45581       No  Metropolitian              16
# 45582       No  Metropolitian              26
# 45583       No  Metropolitian              36

# %%
df_copy.time_order_picked.str.contains('24').sum()
# Out:
# 0

# %%
df_copy['time_orderd'] = pd.to_datetime(df_copy['order_date']+ ' ' +df_copy['time_orderd'])

# %%
df_copy.tail()
# Out:
#            id delivery_person_id  delivery_person_age  \
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 45579                      4.8            26.902328             75.794257
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        delivery_location_latitude  delivery_location_longitude  order_date  \
# 45579                   26.912328                    75.804257  24-03-2022
# 45580                    0.070000                     0.070000  16-02-2022
# 45581                   13.052394                    80.272439  11-03-2022
# 45582                   11.041753                    77.026241  07-03-2022
# 45583                   23.431058                    85.405731  02-03-2022
#
#               time_orderd time_order_picked weather_conditions  \
# 45579 2022-03-24 11:35:00             11:45              Windy
# 45580 2022-02-16 19:55:00             20:10              Windy
# 45581 2022-11-03 23:50:00          00:05:00             Cloudy
# 45582 2022-07-03 13:35:00             13:40             Cloudy
# 45583 2022-02-03 17:10:00             17:15                Fog
#
#       road_traffic_density  vehicle_condition type_of_order type_of_vehicle  \
# 45579                 High                  1          Meal      motorcycle
# 45580                  Jam                  0        Buffet      motorcycle
# 45581                  Low                  1        Drinks         scooter
# 45582                 High                  0         Snack      motorcycle
# 45583               Medium                  2         Snack         scooter
#
#        multiple_deliveries festival           city  time_taken_min
# 45579                  0.0       No  Metropolitian              32
# 45580                  1.0       No  Metropolitian              36
# 45581                  0.0       No  Metropolitian              16
# 45582                  1.0       No  Metropolitian              26
# 45583                  1.0       No  Metropolitian              36

# %%
df_copy['time_order_picked'] = pd.to_datetime(df_copy['order_date'] + ' '+df_copy['time_order_picked'])
# 45581   2022-11-03 00:05:00 # picked_up time
# 45581   2022-11-03 23:50:00 # ordered time

###  date need to be changed even the diff getting 15 min

df_copy.tail(5)
# Out:
#            id delivery_person_id  delivery_person_age  \
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 45579                      4.8            26.902328             75.794257
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        delivery_location_latitude  delivery_location_longitude  order_date  \
# 45579                   26.912328                    75.804257  24-03-2022
# 45580                    0.070000                     0.070000  16-02-2022
# 45581                   13.052394                    80.272439  11-03-2022
# 45582                   11.041753                    77.026241  07-03-2022
# 45583                   23.431058                    85.405731  02-03-2022
#
#               time_orderd   time_order_picked weather_conditions  \
# 45579 2022-03-24 11:35:00 2022-03-24 11:45:00              Windy
# 45580 2022-02-16 19:55:00 2022-02-16 20:10:00              Windy
# 45581 2022-11-03 23:50:00 2022-11-03 00:05:00             Cloudy
# 45582 2022-07-03 13:35:00 2022-07-03 13:40:00             Cloudy
# 45583 2022-02-03 17:10:00 2022-02-03 17:15:00                Fog
#
#       road_traffic_density  vehicle_condition type_of_order type_of_vehicle  \
# 45579                 High                  1          Meal      motorcycle
# 45580                  Jam                  0        Buffet      motorcycle
# 45581                  Low                  1        Drinks         scooter
# 45582                 High                  0         Snack      motorcycle
# 45583               Medium                  2         Snack         scooter
#
#        multiple_deliveries festival           city  time_taken_min
# 45579                  0.0       No  Metropolitian              32
# 45580                  1.0       No  Metropolitian              36
# 45581                  0.0       No  Metropolitian              16
# 45582                  1.0       No  Metropolitian              26
# 45583                  1.0       No  Metropolitian              36

# %%
import time
import datetime

# %%
time.mktime((pd.to_datetime(df_copy['time_order_picked'].iloc[0])).timetuple())
# Out:
# 1670044200.0

# %%
time.mktime((pd.to_datetime(df_copy['time_orderd'].iloc[0])).timetuple())
# Out:
# 1670043300.0

# %%
time.mktime((pd.to_datetime(df_copy['time_order_picked'].iloc[0])).timetuple()) - time.mktime((pd.to_datetime(df_copy['time_orderd'].iloc[0])).timetuple())
# Out:
# 900.0

# %%
(time.mktime((pd.to_datetime(df_copy['time_order_picked'].iloc[0])).timetuple()) - time.mktime((pd.to_datetime(df_copy['time_orderd'].iloc[0])).timetuple()) )/60
# Out:
# 15.0

# %%
# time taken to pick up

(time.mktime((pd.to_datetime(df_copy['time_order_picked'].iloc[0])).timetuple()) - 
 
             time.mktime((pd.to_datetime(df_copy['time_orderd'].iloc[0])).timetuple()) )/60
# Out:
# 15.0

# %%
diff_time = pd.to_datetime(df_copy['time_order_picked']) - pd.to_datetime(df_copy['time_orderd'])

# 45581   -1 days +00:15:00

diff_time.tail()
# Out:
# 45579     0 days 00:10:00
# 45580     0 days 00:15:00
# 45581   -1 days +00:15:00
# 45582     0 days 00:05:00
# 45583     0 days 00:05:00
# dtype: timedelta64[ns]

# %%
diff_time.dt.seconds/60
# Out:
# 0        15.0
# 1        10.0
# 2        10.0
# 3        10.0
# 4        15.0
#          ...
# 45579    10.0
# 45580    15.0
# 45581    15.0
# 45582     5.0
# 45583     5.0
# Length: 35818, dtype: float64

# %%
difference = (pd.to_datetime(df_copy['time_order_picked']) - pd.to_datetime(df_copy['time_orderd'])).dt.seconds/60 
difference
# Out:
# 0        15.0
# 1        10.0
# 2        10.0
# 3        10.0
# 4        15.0
#          ...
# 45579    10.0
# 45580    15.0
# 45581    15.0
# 45582     5.0
# 45583     5.0
# Length: 35818, dtype: float64

# %%
len(df_copy.columns)
# Out:
# 20

# %% [markdown]
# df_copy = df_copy.rename(columns={'preparation_time': 'preparation_time_min'})

# %%
df_copy.insert(loc=19, column='preparation_time_min', value=difference)

# %%
df_copy.tail()
# Out:
#            id delivery_person_id  delivery_person_age  \
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 45579                      4.8            26.902328             75.794257
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        delivery_location_latitude  delivery_location_longitude  order_date  \
# 45579                   26.912328                    75.804257  24-03-2022
# 45580                    0.070000                     0.070000  16-02-2022
# 45581                   13.052394                    80.272439  11-03-2022
# 45582                   11.041753                    77.026241  07-03-2022
# 45583                   23.431058                    85.405731  02-03-2022
#
#               time_orderd   time_order_picked weather_conditions  \
# 45579 2022-03-24 11:35:00 2022-03-24 11:45:00              Windy
# 45580 2022-02-16 19:55:00 2022-02-16 20:10:00              Windy
# 45581 2022-11-03 23:50:00 2022-11-03 00:05:00             Cloudy
# 45582 2022-07-03 13:35:00 2022-07-03 13:40:00             Cloudy
# 45583 2022-02-03 17:10:00 2022-02-03 17:15:00                Fog
#
#       road_traffic_density  vehicle_condition type_of_order type_of_vehicle  \
# 45579                 High                  1          Meal      motorcycle
# 45580                  Jam                  0        Buffet      motorcycle
# 45581                  Low                  1        Drinks         scooter
# 45582                 High                  0         Snack      motorcycle
# 45583               Medium                  2         Snack         scooter
#
#        multiple_deliveries festival           city  preparation_time_min  \
# 45579                  0.0       No  Metropolitian                  10.0
# 45580                  1.0       No  Metropolitian                  15.0
# 45581                  0.0       No  Metropolitian                  15.0
# 45582                  1.0       No  Metropolitian                   5.0
# 45583                  1.0       No  Metropolitian                   5.0
#
#        distance_to_delivery_km  time_taken_min
# 45579                     1.49              32
# 45580                    11.02              36
# 45581                     4.66              16
# 45582                     6.24              26
# 45583                    12.09              36

# %% [markdown]
# ## Longitude and latitude to find the distance (radius)

# %%
    df_copy.sample(5)
# Out:
#            id delivery_person_id  delivery_person_age  \
# 43420  0x6817      SURRES19DEL02                 20.0
# 14207  0x74d0     INDORES19DEL02                 31.0
# 37887  0xd726      KNPRES03DEL02                 37.0
# 13528   0x7b2      SURRES12DEL02                 34.0
# 2032   0x1e92     CHENRES17DEL01                 22.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 43420                      4.6            21.149669             72.772629
# 14207                      3.6            22.745536             75.893106
# 37887                      5.0            26.469003             80.316344
# 13528                      4.3            21.183434             72.814492
# 2032                       4.0            13.045479             80.233110
#
#        delivery_location_latitude  delivery_location_longitude  order_date  \
# 43420                   21.279669                    72.902629  02-03-2022
# 14207                   22.875536                    76.023106  27-03-2022
# 37887                   26.519003                    80.366344  15-02-2022
# 13528                   21.313434                    72.944492  16-03-2022
# 2032                    13.115479                    80.303110  16-03-2022
#
#               time_orderd   time_order_picked weather_conditions  \
# 43420 2022-02-03 23:35:00 2022-02-03 23:40:00             Stormy
# 14207 2022-03-27 17:35:00 2022-03-27 17:45:00             Stormy
# 37887 2022-02-15 23:25:00 2022-02-15 23:40:00                Fog
# 13528 2022-03-16 23:35:00 2022-03-16 23:40:00             Cloudy
# 2032  2022-03-16 20:15:00 2022-03-16 20:30:00             Stormy
#
#       road_traffic_density  vehicle_condition type_of_order type_of_vehicle  \
# 43420                  Low                  2        Drinks      motorcycle
# 14207               Medium                  2         Snack      motorcycle
# 37887                  Low                  2        Drinks         scooter
# 13528                  Low                  1        Buffet         scooter
# 2032                   Jam                  0        Buffet      motorcycle
#
#        multiple_deliveries festival           city  preparation_time  \
# 43420                  0.0       No          Urban               5.0
# 14207                  NaN       No  Metropolitian              10.0
# 37887                  1.0       No  Metropolitian              15.0
# 13528                  0.0       No  Metropolitian               5.0
# 2032                   2.0       No  Metropolitian              15.0
#
#        time_taken_min
# 43420              18
# 14207              38
# 37887              16
# 13528              37
# 2032               39

# %% [raw]
# def haversine_np(lon1, lat1, lon2, lat2):
#     """
#     Calculate the great circle distance between two points
#     on the earth (specified in decimal degrees)
#
#     All args must be of equal length.
#
#     """
#     lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
#
#     dlon = lon2 - lon1
#     dlat = lat2 - lat1
#
#     a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
#
#     c = 2 * np.arcsin(np.sqrt(a))
#     km = 6378 * c
#     return km

# %%
def haversine_np(lon1, lat1, lon2, lat2):
    
     """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    

    """
        
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
    
    dist_lon = lon2-lon1
    dist_lat = lat2-lat1
    
    a = np.sin(dist_lat/2)**2 + np.cos(lat1) *np.cos(lat2) * np.sin(dist_lon/2)**2
    
    c = 2 * np.arcsin(np.sqrt(a))
    
    km = 6378 * c
    
    return km

# %% [raw]
# import numpy as np
# import pandas
# lon1, lon2, lat1, lat2 = np.random.randn(4, 1000000)
# df = pandas.DataFrame(data={'lon1':lon1,'lon2':lon2,'lat1':lat1,'lat2':lat2})
# km = haversine_np(df['lon1'],df['lat1'],df['lon2'],df['lat2'])
#
# ----
# distance_km = haversine_np(d2['Restaurant_longitude'],d2['Restaurant_latitude'],d2['Delivery_location_longitude'],d2['Delivery_location_latitude'])
# ---
#
# d2.insert(loc=20,column='Distance',value=distance_km.round(2))
# ----
#
# distance_km.round(2)

# %%
lon1, lon2, lat1, lat2 = np.random.randn(4, 1000000)

df_location = pd.DataFrame(data={'lon1': lon1, 'lon2': lon2, 'lat1': lat1, 'lat2':lat2})
df_location
# Out:
#             lon1      lon2      lat1      lat2
# 0       0.471797 -0.974524  0.863003 -0.559070
# 1      -1.304590  0.535306 -0.171063 -0.851381
# 2      -0.012636 -0.175141  0.481796  0.076625
# 3      -0.731285 -0.881953  0.551298 -0.065032
# 4      -0.207176 -0.358517  0.252829 -0.222475
# ...          ...       ...       ...       ...
# 999995  0.016446  1.166420  0.019151 -0.732683
# 999996  1.152794  0.300266  0.113214 -0.333529
# 999997  0.402446  1.297514 -0.007776  0.117097
# 999998  1.164041  0.179224  0.401568 -0.213781
# 999999 -0.431853 -0.330745 -0.713477  0.041472
#
# [1000000 rows x 4 columns]

# %%
distance_km = haversine_np(df_copy['restaurant_longitude'], df_copy['restaurant_latitude'], df_copy['delivery_location_longitude'], df_copy['delivery_location_latitude'])
distance_km
# Out:
# 0        10.291878
# 1         6.249177
# 2        13.803009
# 3         2.933477
# 4        19.417930
#            ...
# 45579     1.491483
# 45580    11.019829
# 45581     4.662312
# 45582     6.239241
# 45583    12.087662
# Length: 35818, dtype: float64

# %%
len(df_copy.columns)
# Out:
# 21

# %% [markdown]
# df_copy = df_copy.rename(columns={'distance_to_delivery': 'distance_to_delivery_km'})

# %%
df_copy.insert(loc=20, column='distance_to_delivery_km', value=distance_km.round(2))

# %%
df_copy.tail()
# Out:
#            id delivery_person_id  delivery_person_age  \
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 45579                      4.8            26.902328             75.794257
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        delivery_location_latitude  delivery_location_longitude  order_date  \
# 45579                   26.912328                    75.804257  24-03-2022
# 45580                    0.070000                     0.070000  16-02-2022
# 45581                   13.052394                    80.272439  11-03-2022
# 45582                   11.041753                    77.026241  07-03-2022
# 45583                   23.431058                    85.405731  02-03-2022
#
#               time_orderd   time_order_picked weather_conditions  \
# 45579 2022-03-24 11:35:00 2022-03-24 11:45:00              Windy
# 45580 2022-02-16 19:55:00 2022-02-16 20:10:00              Windy
# 45581 2022-11-03 23:50:00 2022-11-03 00:05:00             Cloudy
# 45582 2022-07-03 13:35:00 2022-07-03 13:40:00             Cloudy
# 45583 2022-02-03 17:10:00 2022-02-03 17:15:00                Fog
#
#       road_traffic_density  vehicle_condition type_of_order type_of_vehicle  \
# 45579                 High                  1          Meal      motorcycle
# 45580                  Jam                  0        Buffet      motorcycle
# 45581                  Low                  1        Drinks         scooter
# 45582                 High                  0         Snack      motorcycle
# 45583               Medium                  2         Snack         scooter
#
#        multiple_deliveries festival           city  preparation_time  \
# 45579                  0.0       No  Metropolitian              10.0
# 45580                  1.0       No  Metropolitian              15.0
# 45581                  0.0       No  Metropolitian              15.0
# 45582                  1.0       No  Metropolitian               5.0
# 45583                  1.0       No  Metropolitian               5.0
#
#        distance_to_delivery  time_taken_min
# 45579                  1.49              32
# 45580                 11.02              36
# 45581                  4.66              16
# 45582                  6.24              26
# 45583                 12.09              36

# %%
df_copy.shape
# Out:
# (35818, 22)

# %%
df_copy.weather_conditions.unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny'],
#       dtype=object)

# %%
df_copy.weather_conditions.dtype
# Out:
# dtype('O')

# %%
df_copy.road_traffic_density.unique()
# Out:
# array(['Jam', 'High', 'Medium', 'Low'], dtype=object)

# %%
df_copy.vehicle_condition.unique()
# Out:
# array([2, 1, 0])

# %%
df_copy.vehicle_condition.dtype
# Out:
# dtype('int64')

# %%
df_copy.type_of_order.unique()
# Out:
# array(['Snack', 'Meal', 'Drinks', 'Buffet'], dtype=object)

# %%
df_copy.type_of_vehicle.unique()
# Out:
# array(['motorcycle', 'scooter', 'electric_scooter'], dtype=object)

# %%
df_copy.multiple_deliveries	.unique()
# Out:
# array([ 3.,  1.,  0., nan,  2.])

# %%
df_copy.festival.unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df_copy.festival.dtype
# Out:
# dtype('O')

# %%
df_copy.city.unique()
# Out:
# array(['Metropolitian', 'Urban', 'Semi-Urban', nan], dtype=object)

# %%
df_copy.time_taken_min.dtype
# Out:
# dtype('int64')

# %%
df_copy.tail()
# Out:
#            id delivery_person_id  delivery_person_age  \
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 45579                      4.8            26.902328             75.794257
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        delivery_location_latitude  delivery_location_longitude  order_date  \
# 45579                   26.912328                    75.804257  24-03-2022
# 45580                    0.070000                     0.070000  16-02-2022
# 45581                   13.052394                    80.272439  11-03-2022
# 45582                   11.041753                    77.026241  07-03-2022
# 45583                   23.431058                    85.405731  02-03-2022
#
#               time_orderd   time_order_picked weather_conditions  \
# 45579 2022-03-24 11:35:00 2022-03-24 11:45:00              Windy
# 45580 2022-02-16 19:55:00 2022-02-16 20:10:00              Windy
# 45581 2022-11-03 23:50:00 2022-11-03 00:05:00             Cloudy
# 45582 2022-07-03 13:35:00 2022-07-03 13:40:00             Cloudy
# 45583 2022-02-03 17:10:00 2022-02-03 17:15:00                Fog
#
#       road_traffic_density  vehicle_condition type_of_order type_of_vehicle  \
# 45579                 High                  1          Meal      motorcycle
# 45580                  Jam                  0        Buffet      motorcycle
# 45581                  Low                  1        Drinks         scooter
# 45582                 High                  0         Snack      motorcycle
# 45583               Medium                  2         Snack         scooter
#
#        multiple_deliveries festival           city  preparation_time_min  \
# 45579                  0.0       No  Metropolitian                  10.0
# 45580                  1.0       No  Metropolitian                  15.0
# 45581                  0.0       No  Metropolitian                  15.0
# 45582                  1.0       No  Metropolitian                   5.0
# 45583                  1.0       No  Metropolitian                   5.0
#
#        distance_to_delivery_km  time_taken_min
# 45579                     1.49              32
# 45580                    11.02              36
# 45581                     4.66              16
# 45582                     6.24              26
# 45583                    12.09              36

# %%
df_copy.to_csv('cleaned_food_delivery_dataset_.csv', index=False)

# %%
pd.read_csv('cleaned_food_delivery_dataset_.csv')
# Out:
#            id delivery_person_id  delivery_person_age  \
# 0      0xcdcd      DEHRES17DEL01                 36.0
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 35813  0x7c09      JAPRES04DEL01                 30.0
# 35814  0xd641      AGRRES16DEL01                 21.0
# 35815  0x4f8d     CHENRES08DEL03                 30.0
# 35816  0x5eee    COIMBRES11DEL01                 20.0
# 35817  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        delivery_person_ratings  restaurant_latitude  restaurant_longitude  \
# 0                          4.2            30.327968             78.046106
# 1                          4.7            10.003064             76.307589
